# %%
import warnings
warnings.filterwarnings('ignore')
import pickle
import numpy as np
import pandas as pd
import json
from textblob import TextBlob
import nltk
from scipy import spatial
import torch
import spacy
en_nlp = spacy.load('en')

# %% [markdown]
# # Convert Json to Pandas Dataframe

# %%
train = pd.read_json("data/train-v2.0.json")

# %%
valid = pd.read_json("data/dev-v2.0.json")

# %%
train.shape, valid.shape
# Out:
# ((442, 2), (35, 2))

# %%
train.head(3)
# Out:
#                                                 data version
# 0  {'title': 'Beyoncé', 'paragraphs': [{'qas': [{...    v2.0
# 1  {'title': 'Frédéric_Chopin', 'paragraphs': [{'...    v2.0
# 2  {'title': 'Sino-Tibetan_relations_during_the_M...    v2.0

# %%
#train.iloc[1,0]['paragraphs'][0]

# %%
# add data to a dataframe
contexts = []
questions = []
answers = []
answers_text = []
answers_start = []
for i in range(train.shape[0]):
    topic = train.iloc[i,0]['paragraphs']
    for sub_para in topic:
        for q_a in sub_para['qas']:
            questions.append(q_a['question'])
            if q_a['answers']:
                answers.append("yes")
                answers_start.append(q_a['answers'][0]['answer_start'])
                answers_text.append(q_a['answers'][0]['text'])
            elif q_a['plausible_answers']:
                answers_start.append(q_a['plausible_answers'][0]['answer_start'])
                answers_text.append(q_a['plausible_answers'][0]['text'])
                answers.append("no")
            contexts.append(sub_para['context'])
df = pd.DataFrame({"context":contexts, "question": questions, "answers":answers, "answer_start": answers_start, "text": answers_text})

# %%
# df = df.iloc[:1000]
# load data in csv file
df.to_csv("data/train_with_answers.csv", index = None)

# %% [markdown]
# # Create dictionary of sentence embeddings for faster computation

# %%
paras = list(df["context"].drop_duplicates().reset_index(drop= True))

# %%
len(paras)
# Out:
# 19029

# %%
blob = TextBlob(" ".join(paras))
sentences = [item.raw for item in blob.sentences]

# %%
from InferSent.models import InferSent 
MODEL_PATH =  'InferSent/encoder/infersent1.pkl'
params_model = {'bsize': 64, 'word_emb_dim': 300, 'enc_lstm_dim': 2048,
                'pool_type': 'max', 'dpout_model': 0.0, 'version': 1}
model = InferSent(params_model)

W2V_PATH = 'InferSent/dataset/GloVe/glove.840B.300d.txt'
model.set_w2v_path(W2V_PATH)
#infersent.set_glove_path("InferSent/dataset/GloVe/glove.840B.300d.txt")

# %%
model.build_vocab(sentences, tokenize=True)
# Out:
# Found 89447(/110298) words with w2v vectors
# Vocab size : 89447

# %%
len(sentences)
# Out:
# 93280

# %%
import time
t0 = time.time()
dict_embeddings = {}
for i in range(len(sentences)):
    if i ==0:
        print(sentences[i])
    if i%1000 == 0:
        t1 = time.time()
        total = t1-t0
        print("encoding question ",i," time since beginning:", total)
    dict_embeddings[sentences[i]] = model.encode([sentences[i]], tokenize=True)
# Out:
# Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress.
# encoding question  0  time since beginning: 0.0004284381866455078
# encoding question  1000  time since beginning: 525.504912853241
# encoding question  2000  time since beginning: 1070.9987246990204

# %%
# encode questions
questions = list(df["question"])
len(questions)
# Out:
# 130319

# %%
dict_embeddings['Architecturally, the school has a Catholic character.'][0]
# Out:
# array([0.01324056, 0.02752344, 0.03426428, ..., 0.04948811, 0.02405655,
#        0.02240689], dtype=float32)

# %%
t0 = time.time()
for i in range(len(questions)):
    if i ==0:
        print(questions[i])
    if i%1000 == 0:
        t1 = time.time()
        total = t1-t0
        print("encoding number ",i," time since beginning:", total)
    dict_embeddings[questions[i]] = model.encode([questions[i]], tokenize=True)
# Out:
# When did Beyonce start becoming popular?
# encoding number  0  time since beginning: 0.0007388591766357422
# encoding number  1000  time since beginning: 189.55568599700928
# encoding number  2000  time since beginning: 379.7590928077698
# encoding number  3000  time since beginning: 561.4019029140472
# encoding number  4000  time since beginning: 746.5095179080963
# encoding number  5000  time since beginning: 947.409910440445
# encoding number  6000  time since beginning: 1133.6747341156006
# encoding number  7000  time since beginning: 1330.9012627601624
# encoding number  8000  time since beginning: 1518.382853269577
# encoding number  9000  time since beginning: 1712.0913274288177
# encoding number  10000  time since beginning: 1896.5042510032654
# encoding number  11000  time since beginning: 2084.3207371234894
# encoding number  12000  time since beginning: 2274.1478412151337
# encoding number  13000  time since beginning: 2450.114104986191
# encoding number  14000  time since beginning: 2630.552731513977
# encoding number  15000  time since beginning: 2815.491475343704
# encoding number  16000  time since beginning: 2991.574739217758
# encoding number  17000  time since beginning: 3169.0154643058777
# encoding number  18000  time since beginning: 3337.3261198997498
# encoding number  19000  time since beginning: 3544.6786592006683
# encoding number  20000  time since beginning: 3748.0189385414124
# encoding number  21000  time since beginning: 3939.225842475891
# encoding number  22000  time since beginning: 4115.8123989105225
# encoding number  23000  time since beginning: 4305.533009290695
# encoding number  24000  time since beginning: 4538.178515911102
# encoding number  25000  time since beginning: 4773.444786071777
# encoding number  26000  time since beginning: 4953.496711730957
# encoding number  27000  time since beginning: 5146.337839841843
# encoding number  28000  time since beginning: 5343.10419011116
# encoding number  29000  time since beginning: 5531.717268228531
# encoding number  30000  time since beginning: 5725.866121530533
# encoding number  31000  time since beginning: 5909.191340446472
# encoding number  32000  time since beginning: 6094.933525085449
# encoding number  33000  time since beginning: 6270.179474115372
# encoding number  34000  time since beginning: 6464.288206100464
# encoding number  35000  time since beginning: 6655.554151773453
# encoding number  36000  time since beginning: 6838.15508890152
# encoding number  37000  time since beginning: 7029.110683917999
# encoding number  38000  time since beginning: 7211.412789344788
# encoding number  39000  time since beginning: 7380.02724313736
# encoding number  40000  time since beginning: 7566.197456598282
# encoding number  41000  time since beginning: 7755.536872625351
# encoding number  42000  time since beginning: 7934.944013118744
# encoding number  43000  time since beginning: 8121.702731132507
# encoding number  44000  time since beginning: 8309.716777086258
# encoding number  45000  time since beginning: 8494.417332410812
# encoding number  46000  time since beginning: 8704.826982498169
# encoding number  47000  time since beginning: 8880.026676893234
# encoding number  48000  time since beginning: 9069.770976781845
# encoding number  49000  time since beginning: 9242.967811346054
# encoding number  50000  time since beginning: 9424.635658502579
# encoding number  51000  time since beginning: 9593.657606601715
# encoding number  52000  time since beginning: 9778.691653251648
# encoding number  53000  time since beginning: 9971.083862781525
# encoding number  54000  time since beginning: 10162.023306369781
# encoding number  55000  time since beginning: 10348.110499382019
# encoding number  56000  time since beginning: 10530.253375053406
# encoding number  57000  time since beginning: 10717.73744058609
# encoding number  58000  time since beginning: 10904.551050662994
# encoding number  59000  time since beginning: 11075.179097652435
# encoding number  60000  time since beginning: 11260.515809059143
# encoding number  61000  time since beginning: 11435.627720594406
# encoding number  62000  time since beginning: 11626.514843940735
# encoding number  63000  time since beginning: 11810.759189844131
# encoding number  64000  time since beginning: 11987.551421165466
# encoding number  65000  time since beginning: 12191.844026088715
# encoding number  66000  time since beginning: 12380.740084409714
# encoding number  67000  time since beginning: 12562.66035246849
# encoding number  68000  time since beginning: 12739.759616613388
# encoding number  69000  time since beginning: 12934.203293800354
# encoding number  70000  time since beginning: 13109.724363803864
# encoding number  71000  time since beginning: 13279.16431260109
# encoding number  72000  time since beginning: 13470.989264249802
# encoding number  73000  time since beginning: 13660.3781645298
# encoding number  74000  time since beginning: 13876.073824167252
# encoding number  75000  time since beginning: 14061.52979683876
# encoding number  76000  time since beginning: 14250.266466379166
# encoding number  77000  time since beginning: 14428.343517780304
# encoding number  78000  time since beginning: 14604.111337661743
# encoding number  79000  time since beginning: 14783.798370361328
# encoding number  80000  time since beginning: 14959.913561820984
# encoding number  81000  time since beginning: 15128.53352856636
# encoding number  82000  time since beginning: 15320.248168230057
# encoding number  83000  time since beginning: 15507.660450696945
# encoding number  84000  time since beginning: 15683.717847824097
# encoding number  85000  time since beginning: 15867.023750066757
# encoding number  86000  time since beginning: 16074.301013708115
# encoding number  87000  time since beginning: 16266.723507404327
# encoding number  88000  time since beginning: 16459.04773044586
# encoding number  89000  time since beginning: 16643.356140375137
# encoding number  90000  time since beginning: 16854.522787570953
# encoding number  91000  time since beginning: 17062.531670331955
# encoding number  92000  time since beginning: 17276.022437810898
# encoding number  93000  time since beginning: 17478.557972431183
# encoding number  94000  time since beginning: 17695.99220585823
# encoding number  95000  time since beginning: 17883.276478528976
# encoding number  96000  time since beginning: 18099.448924779892
# encoding number  97000  time since beginning: 18298.66717147827
# encoding number  98000  time since beginning: 18523.599412679672
# encoding number  99000  time since beginning: 18710.88181424141
# encoding number  100000  time since beginning: 18896.540576696396
# encoding number  101000  time since beginning: 19120.338594198227
# encoding number  102000  time since beginning: 19332.757140874863
# encoding number  103000  time since beginning: 19563.186153411865
# encoding number  104000  time since beginning: 19749.367030858994
# encoding number  105000  time since beginning: 19952.43519759178
# encoding number  106000  time since beginning: 20167.93412232399
# encoding number  107000  time since beginning: 20393.145489931107
# encoding number  108000  time since beginning: 20596.90569782257
# encoding number  109000  time since beginning: 20804.772587776184
# encoding number  110000  time since beginning: 21001.62266087532
# encoding number  111000  time since beginning: 21205.835313796997
# encoding number  112000  time since beginning: 21439.924845457077
# encoding number  113000  time since beginning: 21660.461206436157
# encoding number  114000  time since beginning: 21890.332434654236
# encoding number  115000  time since beginning: 22080.65700984001
# encoding number  116000  time since beginning: 22266.724959611893
# encoding number  117000  time since beginning: 22475.6609582901
# encoding number  118000  time since beginning: 22679.948259592056
# encoding number  119000  time since beginning: 22871.740003824234
# encoding number  120000  time since beginning: 23066.61696910858
# encoding number  121000  time since beginning: 23260.221135377884
# encoding number  122000  time since beginning: 23487.032634973526
# encoding number  123000  time since beginning: 23767.824201583862
# encoding number  124000  time since beginning: 23966.301774024963
# encoding number  125000  time since beginning: 24171.218469142914
# encoding number  126000  time since beginning: 24388.053683042526
# encoding number  127000  time since beginning: 24582.220937252045
# encoding number  128000  time since beginning: 24784.46029639244
# encoding number  129000  time since beginning: 24961.029406547546
# encoding number  130000  time since beginning: 25146.891056537628

# %%
#dict_embeddings['Architecturally, the school has a Catholic character.'][0]

# %%
d1 = {key:dict_embeddings[key] for i, key in enumerate(dict_embeddings) if i % 2 == 0}
d2 = {key:dict_embeddings[key] for i, key in enumerate(dict_embeddings) if i % 2 == 1}

# %%
d2
# Out:
# {'The Wii version makes use of what kind of sensors?': array([[ 0.02203822, -0.00702705,  0.0667559 , ...,  0.02912565,
#           0.02496875,  0.02337021]], dtype=float32),
#  'They may feel certain pain treatment is against their religion.': array([[0.02041637, 0.01720555, 0.03322755, ..., 0.02729459, 0.0281477 ,
#          0.06075768]], dtype=float32),
#  'Why was that? ': array([[ 0.03173946, -0.00754874,  0.03960577, ...,  0.01644378,
#           0.00585065,  0.02240689]], dtype=float32),
#  'When did his sister come to stay with Chopin?': array([[0.02208563, 0.05010815, 0.03100789, ..., 0.02270504, 0.02317609,
#          0.02240689]], dtype=float32),
#  'Gaddafi\'s government was frequently criticized for not being democratic, with Freedom House consistently giving Libya under Gaddafi the "Not Free" ranking for civil liberties and political rights.': array([[0.04876262, 0.02497183, 0.04418193, ..., 0.0215456 , 0.02838127,
#          0.04938416]], dtype=float32),
#  "How many square miles is is Detroit's urban area?": array([[0.0098386 , 0.00906822, 0.03234916, ..., 0.05746893, 0.01636353,
#          0.02775954]], dtype=float32),
#  'That council also denounced various heresies and schisms, many of which continued to preoccupy his 45-year-long episcopate (c. 8 June 328 – 2 May 373).': array([[0.01747326, 0.03206939, 0.05068207, ..., 0.0634632 , 0.0372877 ,
#          0.02240689]], dtype=float32),
#  'What did Lecturer Polya think about von Nuemann?': array([[ 0.04957345, -0.00706878,  0.02721409, ...,  0.01098065,
#           0.02978454,  0.02616261]], dtype=float32),
#  'Who abolished the policy council?': array([[ 0.03023405,  0.01708778,  0.02931636, ...,  0.00378494,
#          -0.00367823,  0.02240689]], dtype=float32),
#  'What other system did supporters of SNES emulation also take the same stance with?': array([[0.05089458, 0.00555192, 0.03470887, ..., 0.02425789, 0.01676528,
#          0.02624697]], dtype=float32),
#  'To date, the Peace Corps has not returned to the Central African Republic.': array([[0.04857443, 0.03231182, 0.02701528, ..., 0.06057239, 0.0258297 ,
#          0.04249009]], dtype=float32),
#  'Traditional mandolin orchestras remain especially popular in Japan and Germany, but also exist throughout the United States, Europe and the rest of the world.': array([[0.03828038, 0.00614952, 0.04337744, ..., 0.03403765, 0.0278242 ,
#          0.02240689]], dtype=float32),
#  'What two reptiles were particularly of interest for the inclusion of "reptiles" in the Endangered Species Conservation Act?': array([[0.05407341, 0.01329482, 0.04643384, ..., 0.04682932, 0.02698723,
#          0.02240689]], dtype=float32),
#  "What was the verdict in Maclean's trial?": array([[0.01455778, 0.03355469, 0.04149746, ..., 0.02974784, 0.02180731,
#          0.03176108]], dtype=float32),
#  'Along with Barbra Streisand, the Carpenters, Dionne Warwick, Barry Manilow and Olivia Newton-John, what adult contemporary staple found it more difficult to score chart hits in the 1980s?': array([[0.04587993, 0.03954779, 0.05394558, ..., 0.03965563, 0.04302641,
#          0.02240689]], dtype=float32),
#  'What did the Gov. Gen. of Ottawa to donate?': array([[ 0.0366513 ,  0.03003819,  0.0375958 , ...,  0.02800372,
#          -0.00367823,  0.02895202]], dtype=float32),
#  'Frederick Campion Steward pioneered techniques of micropropagation and plant tissue culture controlled by plant hormones.': array([[0.02559778, 0.03296612, 0.06755143, ..., 0.05164358, 0.04292178,
#          0.05642923]], dtype=float32),
#  'What disease is common in the UK?': array([[0.03841665, 0.02729808, 0.02403726, ..., 0.02404266, 0.00439131,
#          0.02240689]], dtype=float32),
#  'What percent of tablets were running Windows in Q1 2012?': array([[ 0.03149666, -0.01569424,  0.04840953, ...,  0.02825204,
#          -0.00186998,  0.02240689]], dtype=float32),
#  'Disagreements following the war have resulted in stalemate punctuated by periods of elevated tension and renewed threats of war.': array([[0.05580786, 0.00409343, 0.03528616, ..., 0.02050377, 0.05755642,
#          0.03522244]], dtype=float32),
#  'The Procession, held at sundown, consists of a non-motorized parade through downtown Tucson featuring many floats, sculptures, and memorials, in which the community is encouraged to participate.': array([[0.05293117, 0.03419661, 0.03030858, ..., 0.04422827, 0.02564663,
#          0.02343664]], dtype=float32),
#  'When did Buddhism apread from India to Tibet?': array([[0.03586785, 0.01038273, 0.02938585, ..., 0.00378494, 0.01642187,
#          0.02558508]], dtype=float32),
#  'Who commanded the French Army of the Rhine?': array([[0.01390263, 0.03180037, 0.00580218, ..., 0.09308405, 0.02777164,
#          0.02240689]], dtype=float32),
#  'Rather than hold any games in the cross town rival Sox Park, the Cubs made arrangements with the August A. Busch, owner of the St. Louis Cardinals, to use Busch Stadium in St. Louis as the Cubs "home field" for the World Series.': array([[0.033042  , 0.04171329, 0.03267717, ..., 0.0930462 , 0.04138205,
#          0.04625682]], dtype=float32),
#  "What happens to a multilateral treaty's rights and obligations among the other parties when just one party withdraws?": array([[0.04934846, 0.03208441, 0.02158955, ..., 0.02191842, 0.02786443,
#          0.02684584]], dtype=float32),
#  'YouTube offers users the ability to view its videos on web pages outside their website.': array([[0.00651278, 0.01672763, 0.02363566, ..., 0.04050976, 0.03454814,
#          0.03916499]], dtype=float32),
#  'In what location was Mahatma Gandhi cremated?': array([[ 0.0334033 , -0.0067936 ,  0.04015458, ...,  0.02015817,
#           0.00061374,  0.02240689]], dtype=float32),
#  'What came into power after the war between Himachal and Sanskrit?': array([[0.0521273 , 0.0302725 , 0.02774589, ..., 0.01822847, 0.03115673,
#          0.02960246]], dtype=float32),
#  'In 1918, after the Russian Revolution, all non-Russian countries declared their independence from the Russian empire, leading to the establishment of the First Republic of Armenia.': array([[0.03104978, 0.02268194, 0.03419221, ..., 0.04620051, 0.0308954 ,
#          0.03383422]], dtype=float32),
#  'How many nations do the twenty-five foreign banks represent?': array([[ 0.03236765, -0.01208092,  0.02276563, ...,  0.01450833,
#           0.00545669,  0.02240689]], dtype=float32),
#  'The word Vacuum stems from what Latin adjective?': array([[0.04456846, 0.00286953, 0.02017444, ..., 0.0655819 , 0.02242061,
#          0.05456444]], dtype=float32),
#  'Which side of the coalitions did Naples, Sicily and Savoy join?': array([[0.04941397, 0.04385659, 0.02768839, ..., 0.03579987, 0.01655944,
#          0.02240689]], dtype=float32),
#  'What do many companies specialize in apropos to hunting?': array([[ 0.01834381,  0.01074335,  0.02379395, ...,  0.03579465,
#          -0.00367823,  0.04138174]], dtype=float32),
#  'What needs to be in sync with ambient temperatures?': array([[0.02503231, 0.02951902, 0.02133483, ..., 0.03287079, 0.04756703,
#          0.02240689]], dtype=float32),
#  'Additionally, Somali women have a long tradition of wearing gold jewelry, particularly bangles.': array([[0.04767449, 0.03523041, 0.03397976, ..., 0.02375706, 0.02307013,
#          0.02334008]], dtype=float32),
#  'Wings represent the grouping of various squadrons, both operational and support, under a single tactical commander reporting to the operational commander and vary in size from several hundred personnel to several thousand.': array([[0.05415179, 0.03518129, 0.05536487, ..., 0.04089705, 0.02407501,
#          0.03165731]], dtype=float32),
#  'What has Strange matter been definitely proven to occur as?': array([[0.04697998, 0.01087435, 0.02783413, ..., 0.02533798, 0.02137785,
#          0.02240689]], dtype=float32),
#  'What type of educational institution does the term madrasa refer?': array([[0.02020975, 0.00397934, 0.0344405 , ..., 0.03635776, 0.02860148,
#          0.02240689]], dtype=float32),
#  'Due to the Budget sequestration in 2013, the USAF was forced to ground many of its squadrons.': array([[0.01800501, 0.03030455, 0.04419405, ..., 0.05196453, 0.01901179,
#          0.03232548]], dtype=float32),
#  "What day did Charleston's airport hit the coldest day on record?": array([[0.01840969, 0.01421504, 0.04726039, ..., 0.03938452, 0.01888171,
#          0.02240689]], dtype=float32),
#  'How many wars occurred pre-1960, that averaged about 5 years?': array([[ 0.04167891, -0.01269473,  0.04689366, ...,  0.03801712,
#           0.0251665 ,  0.02240689]], dtype=float32),
#  'Willam was concerned that Victoria would was being portrayed as what because of her trips to central England?': array([[ 0.03488379,  0.03091021,  0.03620607, ...,  0.02882131,
#          -0.00038705,  0.02240689]], dtype=float32),
#  "St. Patrick's Street, the main street of the city which was remodelled in the mid-2000s, is known for the architecture of the buildings along its pedestrian-friendly route and is the main shopping thoroughfare.": array([[0.0288696 , 0.0254599 , 0.04536834, ..., 0.06148798, 0.0400294 ,
#          0.04808589]], dtype=float32),
#  'What other entertainment buildings can be found in the city?': array([[0.03143418, 0.01942991, 0.03148849, ..., 0.02009648, 0.00585245,
#          0.02240689]], dtype=float32),
#  'He further asserted that "the most remarkable creation of MTV is Madonna.': array([[ 0.01811761, -0.0029374 ,  0.05370558, ...,  0.07807644,
#           0.03437778,  0.02240689]], dtype=float32),
#  'A government was formed by Abdullahi Issa Mohamud and Muhammad Haji Ibrahim Egal other members of the trusteeship and protectorate governments, with Haji Bashir Ismail Yusuf as President of the Somali National Assembly, Aden Abdullah Osman Daar as the President of the Somali Republic and Abdirashid Ali Shermarke as Prime Minister (later to become President from 1967 to 1969).': array([[0.04282577, 0.03921539, 0.10773376, ..., 0.03938382, 0.02664411,
#          0.03528983]], dtype=float32),
#  'How long is the CAP?': array([[0.0212751 , 0.00164988, 0.02058784, ..., 0.03692065, 0.02121166,
#          0.02240689]], dtype=float32),
#  'Among his many arguments Hume also added another important slant to the debate about scientific method — that of the problem of induction.': array([[0.04735354, 0.0383242 , 0.05916512, ..., 0.02933777, 0.04538089,
#          0.03636957]], dtype=float32),
#  'SEM partnered with whom?': array([[0.02113539, 0.00570431, 0.02018773, ..., 0.00879018, 0.00218358,
#          0.03213778]], dtype=float32),
#  'Who is the main character of the story?': array([[0.0218462 , 0.02017806, 0.04546871, ..., 0.04615549, 0.0221771 ,
#          0.02240689]], dtype=float32),
#  "These quickly supplanted the earlier steam driven elevators: exploiting Pascal's law, they provided a much greater force.": array([[0.02284472, 0.03001411, 0.024674  , ..., 0.04042342, 0.02544727,
#          0.0345092 ]], dtype=float32),
#  'How long do TCM Wineclub subscriptions last?': array([[ 0.03188859, -0.00272712,  0.02972128, ...,  0.00767549,
#           0.01499499,  0.02240689]], dtype=float32),
#  'These clocks, called peripheral oscillators, are found in the adrenal gland,[citation needed] oesophagus, lungs, liver, pancreas, spleen, thymus, and skin.': array([[0.02992035, 0.05078482, 0.07699274, ..., 0.02339851, 0.05714372,
#          0.08914822]], dtype=float32),
#  'What caused Muawiya to become less popular?': array([[0.0239623 , 0.02841297, 0.05857494, ..., 0.01765102, 0.02236891,
#          0.03259924]], dtype=float32),
#  'When the continuous attack started, how many guns were firing?': array([[0.05558811, 0.01102015, 0.04735505, ..., 0.00772527, 0.02032958,
#          0.02240689]], dtype=float32),
#  'Post-WWII Royal Navy research on safer CATOBAR recovery eventually led to universal adoption of a landing area angled off axis to allow aircraft who missed the arresting wires to "bolt" and safely return to flight for another landing attempt rather than crashing into aircraft on the forward deck.': array([[0.0214809 , 0.05741535, 0.03769162, ..., 0.08400727, 0.04246461,
#          0.04192799]], dtype=float32),
#  'Northeast Zhejiang, as part of the Yangtze Delta, is flat, more developed, and industrial.': array([[0.02351795, 0.00033667, 0.06008783, ..., 0.03108344, 0.03862661,
#          0.0299525 ]], dtype=float32),
#  'Ireland, which had been held by the King of England as Lord of Ireland, but which strictly speaking had been a feudal possession of the Pope since the Norman invasion was declared a separate kingdom in personal union with England.': array([[0.06597795, 0.04596261, 0.04200809, ..., 0.06308095, 0.03142413,
#          0.02240689]], dtype=float32),
#  'When was the Prussian language extinct?': array([[0.02254696, 0.02280676, 0.01971022, ..., 0.01457162, 0.04328167,
#          0.02240689]], dtype=float32),
#  "Despite their mother's disapproval of Joan's desire to study astronomy, Richard encouraged his sister to explore the universe.": array([[0.03925446, 0.05945206, 0.03220159, ..., 0.06593131, 0.05064992,
#          0.0320274 ]], dtype=float32),
#  'Who said the election was marked by very high turnout?': array([[0.02767743, 0.00755516, 0.04039413, ..., 0.01962193, 0.0391404 ,
#          0.02240689]], dtype=float32),
#  "What conceals an annelid's exterior?": array([[0.01461532, 0.02326695, 0.03293263, ..., 0.02828997, 0.03163967,
#          0.02304462]], dtype=float32),
#  'Often founded by individual pastors, they have little affiliation with historic denominations.': array([[0.04599738, 0.00608168, 0.0069929 , ..., 0.01454187, 0.03484618,
#          0.02240689]], dtype=float32),
#  'Who finished fourth on season two?': array([[ 0.0182377 ,  0.03118186,  0.02677789, ...,  0.06964739,
#          -0.00354229,  0.02240689]], dtype=float32),
#  'When were periods of numerous interracial relationships in the U.S.?': array([[0.03584982, 0.01106577, 0.03147868, ..., 0.02082279, 0.0537734 ,
#          0.04094062]], dtype=float32),
#  'What caused the resurface of the Grecian monotony in politics ?': array([[0.0238394 , 0.00196175, 0.02783244, ..., 0.02476164, 0.02368089,
#          0.02240689]], dtype=float32),
#  'Who founded the Kamdamba dynasty?': array([[ 0.02220721, -0.01228814,  0.01824266, ...,  0.00700283,
#           0.02068244,  0.02240689]], dtype=float32),
#  "Which law abolished Glasgow's police?": array([[ 0.01071525,  0.04434883,  0.03177758, ...,  0.00378494,
#          -0.00367823,  0.02240689]], dtype=float32),
#  'This strange device could be considered a very early equivalent of a CD-ROM.': array([[0.03612813, 0.02714313, 0.05480385, ..., 0.04317909, 0.01855225,
#          0.02240689]], dtype=float32),
#  'What test might courts require software to pass to determine if it is protected or infringing?': array([[0.02902799, 0.04121884, 0.04409633, ..., 0.04351639, 0.03351771,
#          0.03906419]], dtype=float32),
#  'What type of stone is hard to find in Florida?': array([[0.0160109 , 0.03178336, 0.03000699, ..., 0.04130308, 0.00966373,
#          0.02263526]], dtype=float32),
#  'Range and height of the target determined fuse length.': array([[0.00500857, 0.00669332, 0.0462528 , ..., 0.02585644, 0.06120055,
#          0.02261231]], dtype=float32),
#  'Which piece is the best, in terms of preservation condition?': array([[0.01469071, 0.0233737 , 0.03380602, ..., 0.05310836, 0.01376909,
#          0.02831293]], dtype=float32),
#  'Nuchal ("on the neck") organs are paired, ciliated structures found only in polychaetes, and are thought to be chemosensors.': array([[0.02897343, 0.03168757, 0.06467298, ..., 0.02795675, 0.047296  ,
#          0.03909242]], dtype=float32),
#  'After a new round of negotiations, a second date was set and the elections process began in earnest.': array([[0.02900769, 0.05469526, 0.02522977, ..., 0.05991013, 0.01431422,
#          0.02879768]], dtype=float32),
#  'What terms describe the same types of radiation?': array([[0.03121288, 0.01195231, 0.04327131, ..., 0.02419464, 0.02391429,
#          0.02240689]], dtype=float32),
#  "What isn't the name of the University of Kansas's foundation?": array([[0.06745826, 0.01773581, 0.02624283, ..., 0.05641665, 0.03600543,
#          0.0365206 ]], dtype=float32),
#  'What browser was automatically included with OS X?': array([[0.03703733, 0.02067767, 0.0368464 , ..., 0.01864658, 0.02081086,
#          0.04266953]], dtype=float32),
#  ' What international exercises does the RNN partake in?': array([[ 0.01176637, -0.01046123,  0.01934172, ...,  0.04083048,
#           0.01227018,  0.0443118 ]], dtype=float32),
#  'It was later championed by Governor Jay Hammond and Kenai state representative Hugh Malone.': array([[0.03801975, 0.01654224, 0.03059455, ..., 0.02089612, 0.00911307,
#          0.0406167 ]], dtype=float32),
#  'When Napoleon entered Moscow, he expected an offer of peace from whom?': array([[0.0431376 , 0.02069011, 0.03411526, ..., 0.03866704, 0.00564347,
#          0.02240689]], dtype=float32),
#  'What other Microsoft gaming console was Hirai setting his sales goal to beat?': array([[0.01772001, 0.0012289 , 0.03399637, ..., 0.05459212, 0.00275513,
#          0.0524876 ]], dtype=float32),
#  'What did Emperor Wu do to negate the influence of private entrepreneurs?': array([[0.02147707, 0.01338413, 0.01858465, ..., 0.03517664, 0.02692216,
#          0.02356572]], dtype=float32),
#  'How do Asian countries feel about the European attitude towards Burma ?': array([[0.03884263, 0.01283818, 0.02098525, ..., 0.0396489 , 0.01773907,
#          0.04291652]], dtype=float32),
#  'In what year was the French commune forming part of Guadeloupe established?': array([[0.03792695, 0.00625859, 0.02868463, ..., 0.08724485, 0.05453279,
#          0.02240689]], dtype=float32),
#  'Were the elections held in an unbiased manner Burma in 2010 ? ': array([[0.05364924, 0.02744313, 0.02122373, ..., 0.03334529, 0.03065782,
#          0.06782789]], dtype=float32),
#  'Where was the Condemnation of 1727 enacted?': array([[0.01805071, 0.00677586, 0.01728819, ..., 0.02438935, 0.02275581,
#          0.02240689]], dtype=float32),
#  'Many fossil tubes look like those made by modern sessile polychaetes  , but the first tubes clearly produced by polychaetes date from the Jurassic, less than 199 million years ago.': array([[0.05562425, 0.04173383, 0.04438604, ..., 0.04873794, 0.06801501,
#          0.03213632]], dtype=float32),
#  'Who are descendents of various culturally distinct groups?': array([[0.04912352, 0.0009055 , 0.02059644, ..., 0.01999649, 0.02343816,
#          0.02240689]], dtype=float32),
#  'Additional, recent years have seen a surge in popularity of MDMA; between 2010 and 2011, the use of MDMA increased from 1.4% to 2.3% among high school seniors.': array([[0.05919656, 0.01375906, 0.03902335, ..., 0.0579895 , 0.05198207,
#          0.02240689]], dtype=float32),
#  'What locations were seized in the second invasion?': array([[0.0349549 , 0.0237399 , 0.02474667, ..., 0.03658837, 0.01642515,
#          0.02240689]], dtype=float32),
#  "The UK's first polytechnic, the Royal Polytechnic Institution (now the University of Westminster) was founded in 1838 in Regent Street, London.": array([[0.06515002, 0.04668261, 0.0444678 , ..., 0.05005992, 0.04757155,
#          0.02240689]], dtype=float32),
#  'What materials were discs made of in 1889-1894?': array([[0.05447061, 0.01788702, 0.02574993, ..., 0.03108958, 0.02543505,
#          0.02240689]], dtype=float32),
#  'Public universities in Nordic countries were entirely without tuition fees until around 2005.': array([[0.06018703, 0.0054486 , 0.02113502, ..., 0.02923625, 0.0261301 ,
#          0.03062241]], dtype=float32),
#  "Where doesn't uranium accumulate in the body?": array([[0.04522122, 0.00379133, 0.05166164, ..., 0.02990002, 0.01148688,
#          0.05065029]], dtype=float32),
#  'Sexual orientation differs from sexual identity in that it encompasses relationships with others, while sexual identity is a concept of self.': array([[0.01984292, 0.0110365 , 0.03797013, ..., 0.05171686, 0.05175378,
#          0.04838683]], dtype=float32),
#  'Reviews of the various editions of Windows 8 have been mixed.': array([[0.03640123, 0.00572339, 0.02899543, ..., 0.03114488, 0.01204128,
#          0.03550937]], dtype=float32),
#  'What Ukrainian political group was involved in the defeat of the German Empire?': array([[0.05302755, 0.01966091, 0.02798418, ..., 0.03855594, 0.02552281,
#          0.02478276]], dtype=float32),
#  'The earliest examples of neoclassical architecture in Hungary may be found in Vác.': array([[0.0306963 , 0.01621882, 0.03712339, ..., 0.04232932, 0.02255203,
#          0.02240689]], dtype=float32),
#  'Such chalets are typically found in the higher parts of the valleys, as in the Maurienne valley in Savoy, where the amount of snow during the cold months is important.': array([[0.04592628, 0.01246751, 0.03993739, ..., 0.03019704, 0.07592537,
#          0.034614  ]], dtype=float32),
#  'While they were the dominant group of avialans during the Cretaceous period, enantiornithes became extinct along with many other dinosaur groups at the end of the Mesozoic era.': array([[0.05276454, 0.03016413, 0.02363174, ..., 0.04408516, 0.08608227,
#          0.02277129]], dtype=float32),
#  'Although more inclusive than earlier views, this approach to culture still allowed for distinctions between "civilized" and "primitive" or "tribal" cultures.': array([[0.04768937, 0.02548023, 0.050602  , ..., 0.05095309, 0.0384545 ,
#          0.03430547]], dtype=float32),
#  'The cracking creates unpredictable and dangerous crevasses, often invisible under new snowfall, which cause the greatest danger to mountaineers.': array([[0.02456148, 0.03046123, 0.02924947, ..., 0.02605126, 0.04856688,
#          0.02240689]], dtype=float32),
#  'Of the violent crimes reported, 14 were murders, 99 were forcible rapes and 643 were robberies.': array([[0.03616524, 0.01053488, 0.03900576, ..., 0.0067688 , 0.01944594,
#          0.02874521]], dtype=float32),
#  'What is the process of trees growing out to get bigger around called?': array([[0.02673646, 0.03327248, 0.03380607, ..., 0.05013222, 0.01213865,
#          0.02807328]], dtype=float32),
#  'Camillo di Cavour, under orders of Victor Emmanuel II of Piedmont-Sardinia, sent an expeditionary corps of 15,000 soldiers, commanded by General Alfonso La Marmora, to side with French and British forces during the war.': array([[0.08673348, 0.06145233, 0.03743291, ..., 0.11062404, 0.04143159,
#          0.03200191]], dtype=float32),
#  'In this formalism of quantum mechanics, observable quantities such as position or momentum are represented as linear operators acting on the Hilbert space associated with the quantum system.': array([[0.02498879, 0.00685123, 0.04089513, ..., 0.04489758, 0.04189744,
#          0.02892334]], dtype=float32),
#  'In December 2014, ISAF encasing its colors, and Resolute Support began as the NATO operation in Afghanistan.': array([[0.04214157, 0.03535445, 0.04726454, ..., 0.03415814, 0.00947696,
#          0.04513463]], dtype=float32),
#  'In 2012 who placed Beyonce at 16 in the Celebrity List?': array([[0.03583829, 0.03151025, 0.02595339, ..., 0.04651029, 0.03486287,
#          0.02240689]], dtype=float32),
#  'What types of workability is the word commonly used to mean?': array([[0.02214589, 0.02099114, 0.03320267, ..., 0.03228894, 0.0312967 ,
#          0.02844024]], dtype=float32),
#  'In a further behavioral adaptation to supplement crypsis, a number of species have been noted to perform a rocking motion where the body is swayed from side to side that is thought to reflect the movement of leaves or twigs swaying in the breeze.': array([[0.05205711, 0.02797061, 0.07027331, ..., 0.06348616, 0.05406851,
#          0.05148681]], dtype=float32),
#  'What percentage of households earned less than 977 per month?': array([[ 0.05940004, -0.01873964,  0.02561663, ...,  0.03184935,
#          -0.00075873,  0.02240689]], dtype=float32),
#  'In 1807, Thomas Young was possibly the first to use the term "energy" instead of vis viva, in its modern sense.': array([[0.04071735, 0.03432018, 0.03493278, ..., 0.04133242, 0.02509177,
#          0.04212377]], dtype=float32),
#  'Parks in New York City include Central Park, Prospect Park, Flushing Meadows–Corona Park, Forest Park, and Washington Square Park.': array([[0.01157981, 0.03874695, 0.02005109, ..., 0.04188798, 0.0377411 ,
#          0.05755994]], dtype=float32),
#  'What percentage of women have had a heart attack?': array([[0.06090283, 0.02177901, 0.03083246, ..., 0.0222741 , 0.0058365 ,
#          0.02951001]], dtype=float32),
#  'How many hundreds of tons of paper are wasted in the US each year?': array([[0.04751659, 0.04597497, 0.02342558, ..., 0.04024575, 0.0123299 ,
#          0.02240689]], dtype=float32),
#  'What event of the Early Cretaceous caused the proliferation of several species?': array([[0.04717458, 0.00549114, 0.03378964, ..., 0.04784208, 0.09842149,
#          0.02240689]], dtype=float32),
#  'What era was characterized by the Ottoman Empire?': array([[0.02512018, 0.00147538, 0.01875545, ..., 0.02541227, 0.02800733,
#          0.02240689]], dtype=float32),
#  'In March 2014, The Times had an average daily circulation of how many people?': array([[0.04750457, 0.03722342, 0.05488917, ..., 0.04763492, 0.01522676,
#          0.02240689]], dtype=float32),
#  'A temporary secretariat building was built in New Delhi in what year?': array([[0.0322874 , 0.0127865 , 0.02768636, ..., 0.03384479, 0.00145315,
#          0.02240689]], dtype=float32),
#  'What University are in Bath ': array([[ 0.06245623, -0.00288131,  0.02322031, ...,  0.02071287,
#           0.02784516,  0.02240689]], dtype=float32),
#  "What percentage of all global trade went through Liverpool in the 1830's?": array([[0.03194486, 0.01653142, 0.02280757, ..., 0.02742371, 0.0028356 ,
#          0.02630861]], dtype=float32),
#  'Brazil is the second largest with 5 million people claiming German ancestry.': array([[0.04531901, 0.01424409, 0.02422439, ..., 0.05763115, 0.04928593,
#          0.02249686]], dtype=float32),
#  'These attributes are accomplished by applying the principle of "filtered permeability" to the existing irregular network of streets.': array([[0.00890642, 0.01709608, 0.05082491, ..., 0.04726468, 0.05979018,
#          0.02240689]], dtype=float32),
#  'What appointments were  the first step in Indian self-rule?': array([[0.05683906, 0.02859695, 0.02696824, ..., 0.04214918, 0.00914836,
#          0.03130254]], dtype=float32),
#  'How does WINEP bundle the countries of Northwest Africa?': array([[0.04465616, 0.01696653, 0.04452043, ..., 0.04153168, 0.01654546,
#          0.02305058]], dtype=float32),
#  "The difficulty of accessing the region overland from the eastern part of China and the foggy climate hindering the accuracy of Japanese bombing of the Sichuan Basin, made the region the stronghold of Chiang Kai-Shek's Kuomintang government during 1938-45, and led to the Bombing of Chongqing.": array([[0.02716064, 0.02968207, 0.04785355, ..., 0.0483187 , 0.05767127,
#          0.02618257]], dtype=float32),
#  'What country did Pringle cite as having homes with worse proportions than those found in the UK?': array([[0.04643502, 0.03020721, 0.03177753, ..., 0.02160829, 0.02280113,
#          0.02240689]], dtype=float32),
#  'Along with predicting the gun data from tracking the target, what else needed to be known about the target to enable the aimed fire?': array([[0.03673336, 0.03590594, 0.04659009, ..., 0.04103815, 0.03414169,
#          0.02240689]], dtype=float32),
#  'Who developed the first commercial broadcast automation band?': array([[0.03275099, 0.0156016 , 0.03635936, ..., 0.04148245, 0.03384253,
#          0.03282768]], dtype=float32),
#  'When was Marwan recognized as the new caliph in the mosque at Kufa?': array([[0.02992257, 0.02477914, 0.04539092, ..., 0.03448   , 0.05054464,
#          0.02240689]], dtype=float32),
#  "Between 1939 and 1949, how many military officers and personnel weren't trained on the Evanston and Chicago campuses?": array([[0.04552507, 0.02341519, 0.0265211 , ..., 0.06262914, 0.01829778,
#          0.02240689]], dtype=float32),
#  "For example, the District of A'ana has its capital at Leulumoega.": array([[0.01862541, 0.00633209, 0.03976558, ..., 0.03763299, 0.03093957,
#          0.02829375]], dtype=float32),
#  'Copper is the source of the green color in malachite pigments, chemically known as basic copper(II) carbonate.': array([[0.02082239, 0.0392006 , 0.06761472, ..., 0.04917742, 0.04299191,
#          0.03836213]], dtype=float32),
#  "Snow falls on Sinai's mountains and some of the north coastal cities such as Damietta, Baltim, Sidi Barrany, etc.": array([[0.02219003, 0.01184881, 0.03595838, ..., 0.03438939, 0.03291965,
#          0.02792005]], dtype=float32),
#  'Who are they descendants of?': array([[ 0.03590944, -0.00795747,  0.01942134, ...,  0.02589322,
#           0.02930217,  0.02240689]], dtype=float32),
#  'When did registered Republicans become a majority in Oklahoma?': array([[0.05896439, 0.03267568, 0.03805714, ..., 0.02460874, 0.00196597,
#          0.02240689]], dtype=float32),
#  'The Mickey Mouse cartoon of 1939 was repeated twenty minutes later.': array([[0.06055678, 0.01918121, 0.0285208 , ..., 0.04058138, 0.01171325,
#          0.02240689]], dtype=float32),
#  'What were UN sanctions place placed on 2003?': array([[ 0.04408192,  0.0314409 ,  0.02891554, ...,  0.04774063,
#          -0.00367823,  0.02240689]], dtype=float32),
#  'Seeds consist of an endosporic megasporangium surrounded by one or two sheathing layers (integuments).': array([[0.03341712, 0.05357657, 0.06225566, ..., 0.040518  , 0.06053372,
#          0.02240689]], dtype=float32),
#  "What is the least widely accepted explanation of Neptune's formation called?": array([[0.03846444, 0.00427655, 0.04432575, ..., 0.03413409, 0.04425231,
#          0.02543923]], dtype=float32),
#  'Some clothing protects from specific environmental hazards, such as insects, noxious chemicals, weather, weapons, and contact with abrasive substances.': array([[0.04678815, 0.04136038, 0.06617326, ..., 0.04551355, 0.05644593,
#          0.02565573]], dtype=float32),
#  'It is rarely used by politicians themselves in a public context, although at certain times in Canadian history political parties have used other similarly loaded imagery.': array([[0.06774797, 0.01683199, 0.03435602, ..., 0.02460874, 0.02570179,
#          0.02240689]], dtype=float32),
#  'The motif of deceptively realistic naturalism in art (aletheia) is reflected in stories such as that of the painter Zeuxis, who was said to have painted grapes that seemed so real that birds came and pecked at them.': array([[0.04076654, 0.03968439, 0.05561583, ..., 0.08118199, 0.01766654,
#          0.03047627]], dtype=float32),
#  'Most flowering plants require an animal to do the transportation.': array([[0.03492111, 0.03776011, 0.03134081, ..., 0.04481634, 0.00852014,
#          0.02240689]], dtype=float32),
#  'How much were Dell losing in 2002?': array([[ 0.04072893, -0.01910016,  0.06369642, ...,  0.02616626,
#          -0.00367823,  0.03102664]], dtype=float32),
#  'What American carrier was sunk in the Battle of the Coral Sea?': array([[0.03648115, 0.03093828, 0.02034184, ..., 0.03438706, 0.01853735,
#          0.02414485]], dtype=float32),
#  'A court in southern Taiwan ordered the firm to deliver 18 laptops and 76 flat-panel monitors to 31 consumers for NT$490,000 (US$15,120), less than a third of the normal price.': array([[0.06735373, 0.03946112, 0.07330488, ..., 0.04342478, 0.01202481,
#          0.07967483]], dtype=float32),
#  'The ISSP\'s aims are "to raise pupil achievement, improve pupil self-esteem, raise pupil aspirations and improve professional practice across the schools".': array([[0.03412056, 0.01601622, 0.05262733, ..., 0.04238564, 0.03674569,
#          0.04502601]], dtype=float32),
#  'Which form of oak is found furthest south?': array([[0.01529817, 0.01798569, 0.03191599, ..., 0.04771943, 0.03556753,
#          0.02240689]], dtype=float32),
#  'Memories of the Nazi occupation were still strong, and the rearmament of Germany was feared by France too.': array([[0.06745763, 0.0083041 , 0.02930901, ..., 0.03539728, 0.02536355,
#          0.02240689]], dtype=float32),
#  'Where did Feynman receive much inspiration?': array([[0.0418666 , 0.01845024, 0.03178516, ..., 0.04180387, 0.02239075,
#          0.02240689]], dtype=float32),
#  'What exactly does chunking memory allow a person to do?': array([[ 0.0196005 ,  0.03758996,  0.04872773, ...,  0.03782534,
#          -0.00367823,  0.02240689]], dtype=float32),
#  'Where are these cell groups found in humans?': array([[0.04316493, 0.02109993, 0.05092435, ..., 0.03082768, 0.0130393 ,
#          0.02240689]], dtype=float32),
#  'The army was forbidden from considering anything larger than .50-inch.': array([[ 0.03884887,  0.01510319,  0.02543728, ...,  0.02398427,
#          -0.00366986,  0.02240689]], dtype=float32),
#  'Since what year has there been a daily broadcast on All India Radio?': array([[0.05499423, 0.01822184, 0.04611705, ..., 0.02815804, 0.01232833,
#          0.02240689]], dtype=float32),
#  'McWhorter wrote that the existance of the book was what?': array([[0.03032985, 0.02680701, 0.03240529, ..., 0.04526211, 0.03147504,
#          0.02240689]], dtype=float32),
#  'Most of the conspirators were senators, who had a variety of economic, political, or personal motivations for carrying out the assassination.': array([[0.05141384, 0.041422  , 0.03524489, ..., 0.04248399, 0.02448321,
#          0.04109481]], dtype=float32),
#  'What models imply that changes in diversity are guided by stochastic dynamics?': array([[0.03981411, 0.01842573, 0.04390549, ..., 0.08797053, 0.07424957,
#          0.02890443]], dtype=float32),
#  'In what year was College Park Airport declared the first international airport of the Americas?': array([[0.06637847, 0.02285905, 0.05497267, ..., 0.0442964 , 0.02421563,
#          0.05382095]], dtype=float32),
#  'However, under siege from forces from Buenos Aires, the Portuguese withdrew from Montevideo Bay in January 1724, after signing an agreement with the Spaniards.': array([[0.04427562, 0.04223655, 0.02097763, ..., 0.06130667, 0.0254843 ,
#          0.02240689]], dtype=float32),
#  'What tribe formerly ruled Kota?': array([[0.01382841, 0.00645999, 0.02914459, ..., 0.00378494, 0.035607  ,
#          0.02240689]], dtype=float32),
#  'Who was the first president of Palermo?': array([[0.02074497, 0.0211054 , 0.02261015, ..., 0.03840951, 0.01390028,
#          0.02271584]], dtype=float32),
#  'As Darwin was an eminent scientist, his findings were taken seriously and the evidence he presented generated scientific, philosophical, and religious discussion.': array([[0.07090153, 0.04052239, 0.03879757, ..., 0.04260425, 0.05109376,
#          0.04842145]], dtype=float32),
#  'Glover sold poorly with her debut album, and this is also the first season that the runner-up was not signed by a music label.': array([[0.0358278 , 0.05065062, 0.04198236, ..., 0.05178631, 0.00628049,
#          0.02240689]], dtype=float32),
#  'Royal assent is the first stage in what?': array([[0.02621045, 0.02089965, 0.02410784, ..., 0.05460508, 0.01482764,
#          0.02617833]], dtype=float32),
#  'Besides fire, what else is charcoal used for?': array([[0.01977065, 0.03293299, 0.03468218, ..., 0.04377759, 0.00227351,
#          0.02240689]], dtype=float32),
#  'What did 21st century fiction and drama move back toward?': array([[0.04047279, 0.0035751 , 0.02123707, ..., 0.05907029, 0.01255624,
#          0.02554065]], dtype=float32),
#  "The city's charter was granted by Prince John, as Lord of Ireland, in 1185.": array([[0.0267227 , 0.00970915, 0.03884018, ..., 0.04563293, 0.01452557,
#          0.0307624 ]], dtype=float32),
#  'The emergence of humanism was essential to this understanding of the possible utility of universities as well as the revival of interest in knowledge gained from ancient Greek texts.': array([[0.03574158, 0.01238997, 0.0521102 , ..., 0.07220187, 0.03639737,
#          0.02875267]], dtype=float32),
#  'Many nobles were actually surprisingly acting in what way?': array([[ 0.02609254, -0.01276166,  0.02969729, ...,  0.01926738,
#           0.00690658,  0.02240689]], dtype=float32),
#  'Belief is a fundamental aspect of morality in the Quran, and scholars have tried to determine the semantic contents of "belief" and "believer" in the Quran.': array([[0.04265816, 0.0266612 , 0.05107915, ..., 0.04684346, 0.04743188,
#          0.04081257]], dtype=float32),
#  'What Supreme Court case resulted in capital punishment being suspended?': array([[0.03959307, 0.05303818, 0.03626729, ..., 0.01100915, 0.02730823,
#          0.02379567]], dtype=float32),
#  'Wye College campus was finally closed in September 2009.': array([[0.03660883, 0.03747239, 0.02111143, ..., 0.04461244, 0.0224069 ,
#          0.02240689]], dtype=float32),
#  'Under what condition might the polarization of the dielectric be unable to follow the voltage?': array([[0.01978428, 0.036274  , 0.04517742, ..., 0.03369498, 0.06177664,
#          0.02240689]], dtype=float32),
#  'Following the 2007 Federal Election, Dr Brendan Nelson was elected leader by the Parliamentary Liberal Party.': array([[0.07166736, 0.02600774, 0.02927027, ..., 0.04269057, 0.00472458,
#          0.03231485]], dtype=float32),
#  'What philosophy combined with Descartes to push quantum activity in the 20th century?': array([[0.0304888 , 0.00177955, 0.03692877, ..., 0.05239651, 0.02624307,
#          0.03985966]], dtype=float32),
#  'The Sunday Times has a significantly higher circulation than The Times, and sometimes outsells The Sunday Telegraph.': array([[0.0379337 , 0.04574512, 0.05072072, ..., 0.02644447, 0.01639814,
#          0.02240689]], dtype=float32),
#  'Domestic tourism in Iran is one of the largest in the world.': array([[0.01320733, 0.01301006, 0.04267349, ..., 0.03586787, 0.02398039,
#          0.02667196]], dtype=float32),
#  'Art of the Parthians was a mixture of Iranian and Hellenistic artworks, with their main motifs being scenes of royal hunting expeditions and investitures.': array([[0.03787116, 0.01499472, 0.03488754, ..., 0.04724193, 0.03608184,
#          0.04310773]], dtype=float32),
#  'According to the World Wide Fund for Nature and the European Environment Agency, the territory of Greece can be subdivided into six ecoregions: the Illyrian deciduous forests, Pindus Mountains mixed forests, Balkan mixed forests, Rhodope montane mixed forests, Aegean and Western Turkey sclerophyllous and mixed forests and Crete Mediterranean forests.': array([[0.04086956, 0.03526956, 0.02322115, ..., 0.04373517, 0.10111228,
#          0.03513518]], dtype=float32),
#  'The Cronquist system, proposed by Arthur Cronquist in 1968 and published in its full form in 1981, is still widely used but is no longer believed to accurately reflect phylogeny.': array([[0.01585398, 0.03096237, 0.04874397, ..., 0.04434597, 0.07414577,
#          0.02240689]], dtype=float32),
#  'How much more energy does Jupiter radiate than it receives?': array([[0.03110578, 0.00130184, 0.03812502, ..., 0.02020006, 0.0214125 ,
#          0.02240689]], dtype=float32),
#  'The Trolley primarily serves downtown and surrounding urban communities, Mission Valley, east county, and coastal south bay.': array([[0.02850193, 0.01179821, 0.01790881, ..., 0.05279812, 0.0396417 ,
#          0.02304235]], dtype=float32),
#  'Who lanced and never treated the abscess on Queen Victorias arm?': array([[0.05649773, 0.02855452, 0.02984348, ..., 0.04798251, 0.02225572,
#          0.0584686 ]], dtype=float32),
#  'Race anthropologists were pressured to acknowledge findings coming from studies of culture and population genetics, and to revise their conclusions about the sources of phenotypic variation.': array([[0.05412414, 0.02622274, 0.0431984 , ..., 0.06668941, 0.06889545,
#          0.03023749]], dtype=float32),
#  'Department stores today have sections that sell the following: clothing, furniture, home appliances, toys, cosmetics, gardening, toiletries, sporting goods, do it yourself, paint, and hardware and additionally select other lines of products such as food, books, jewelry, electronics, stationery, photographic equipment, baby products, and products for pets.': array([[0.04718905, 0.03993588, 0.06050298, ..., 0.03892702, 0.01898268,
#          0.03605775]], dtype=float32),
#  'Which contestant was surprisingly eliminated during the top four episode? ': array([[0.03028252, 0.00681551, 0.0411021 , ..., 0.01906885, 0.01607291,
#          0.03761296]], dtype=float32),
#  'When was the Consortium founded?': array([[0.0374032 , 0.02706017, 0.01971022, ..., 0.02626622, 0.03174245,
#          0.02254442]], dtype=float32),
#  'Who was a controversial figure due to a corked-bat incident?': array([[0.02918485, 0.04447943, 0.03003084, ..., 0.03073687, 0.01337756,
#          0.02468972]], dtype=float32),
#  'What rating does Cheval Blanc have?': array([[ 0.03486775, -0.00061127,  0.03132989, ...,  0.04322173,
#          -0.00367823,  0.02240689]], dtype=float32),
#  'What calander ends on the vernal equinox?': array([[0.01230815, 0.00604129, 0.01298737, ..., 0.03713072, 0.03007914,
#          0.02240689]], dtype=float32),
#  'Who prompted Eritrea to be federated with Ethiopia in 1950?': array([[0.02233056, 0.03840015, 0.03009737, ..., 0.02462617, 0.03692855,
#          0.02240689]], dtype=float32),
#  'Children were employed in the home, factories and were else in the 20th century?': array([[0.04312067, 0.01798122, 0.03761249, ..., 0.02826447, 0.02077644,
#          0.02240689]], dtype=float32),
#  'What time was Cardinal Eugene Tisserant elected as Pope?': array([[0.01868486, 0.02075692, 0.02554036, ..., 0.0743297 , 0.00487878,
#          0.02979877]], dtype=float32),
#  'Apart from the rule of Aqa Mohammad Khan, the Qajar rule is characterized as a century of misrule.': array([[0.01116556, 0.02612676, 0.0706235 , ..., 0.03695976, 0.03400759,
#          0.02240689]], dtype=float32),
#  'How are the Canadian forces ranked in size compared to other military?': array([[0.0242293 , 0.01668942, 0.04837354, ..., 0.03846778, 0.01433413,
#          0.02653048]], dtype=float32),
#  'Who investigated the efficiency of low-brightness LED at Cardiff University in 1995?': array([[0.06935429, 0.0068519 , 0.05022086, ..., 0.03400309, 0.02564432,
#          0.02240689]], dtype=float32),
#  'In the aftermath of the Eureka Stockade, mass public support for the plight of the miners resulted in major political changes to the colony, including changes to working conditions across local industries including mining, agriculture and manufacturing.': array([[0.06929054, 0.02985689, 0.05540049, ..., 0.04560617, 0.03177587,
#          0.03152634]], dtype=float32),
#  "What UN cities have more impressive skylines than Miami's?": array([[ 0.04186362, -0.01173775,  0.0247346 , ...,  0.04963446,
#           0.00259817,  0.02630861]], dtype=float32),
#  'What was the result of the use of this release of 78 rpm vinyl when used in vintage jukeboxes?': array([[0.02460956, 0.02030222, 0.03745364, ..., 0.04008246, 0.02298537,
#          0.02240689]], dtype=float32),
#  'Who held the equivalent of the post of prime minister under Queen Anne?': array([[0.04816582, 0.03761424, 0.02885376, ..., 0.05599777, 0.01661728,
#          0.03823606]], dtype=float32),
#  "Another dance performed by males is called the fa'ataupati or the slap dance, creating rhythmic sounds by slapping different parts of the body.": array([[0.05283661, 0.02365942, 0.0345019 , ..., 0.03436447, 0.02770679,
#          0.04957508]], dtype=float32),
#  'Which act got rid of the NIA and the CIG?': array([[0.02487703, 0.01655084, 0.02217051, ..., 0.03460162, 0.03666177,
#          0.02736425]], dtype=float32),
#  'At the Battle of Mutina Mark Antony was defeated by the consuls Hirtius and Pansa, who were both killed.': array([[0.06319149, 0.01961091, 0.03511305, ..., 0.04475902, 0.0525138 ,
#          0.03145362]], dtype=float32),
#  'What are the two terms colloquially used to refer to the jurisdiction of NCT of Delhi?': array([[0.02652766, 0.03212516, 0.03187167, ..., 0.03609861, 0.01766276,
#          0.02240689]], dtype=float32),
#  "When did the use of agriculture begin it's spread?": array([[0.03810848, 0.00833641, 0.03048636, ..., 0.06343308, 0.02247769,
#          0.02515484]], dtype=float32),
#  'The middle up segment is mainly occupied by Metro Department Store originated from Singapore and Sogo from Japan.': array([[0.02394063, 0.01180871, 0.05347789, ..., 0.03959578, 0.01073381,
#          0.02240689]], dtype=float32),
#  "Windows 8's tablet market share has also been growing steadily, with 7.4% of tablets running Windows in Q1 2013 according to Strategy Analytics, up from nothing just a year before.": array([[0.03619347, 0.01999844, 0.05773069, ..., 0.04425414, 0.05354569,
#          0.04313867]], dtype=float32),
#  'What is no longer a symptom of both zinc deficiency and excess?': array([[0.02543514, 0.01308171, 0.03596395, ..., 0.01561167, 0.03598268,
#          0.04620818]], dtype=float32),
#  "What company was desktop publishing not unique to at it's beginning?": array([[0.0344995 , 0.0151786 , 0.02439417, ..., 0.06301438, 0.00337834,
#          0.04409584]], dtype=float32),
#  'Shift-work also leads to increased metabolic risks for cardio-metabolic syndrome, hypertension, inflammation.': array([[0.00806808, 0.02810247, 0.06538958, ..., 0.00879331, 0.06956478,
#          0.05534497]], dtype=float32),
#  'After a three-year hiatus, a fifth Digimon series began airing on April 2, 2006.': array([[0.0307363 , 0.03040779, 0.02821102, ..., 0.05479114, 0.01326228,
#          0.02240689]], dtype=float32),
#  'What is not created until the copyright owner registers the copyright?': array([[0.0450674 , 0.01918934, 0.02165223, ..., 0.05504353, 0.01290991,
#          0.02240689]], dtype=float32),
#  'How do servo motors differ from stepper motors?': array([[-0.00442047,  0.01094496,  0.04857459, ...,  0.01502421,
#           0.00445589,  0.02615642]], dtype=float32),
#  'What are some of the members of the Armed Forces Council?': array([[0.04236529, 0.0326322 , 0.03548132, ..., 0.04118366, 0.01830358,
#          0.02240689]], dtype=float32),
#  'During what time did copper beads become widely used in India?': array([[0.04404015, 0.03126811, 0.04546933, ..., 0.00860366, 0.02220526,
#          0.02596457]], dtype=float32),
#  'What opened the era of Germany?': array([[0.02330184, 0.00878667, 0.02316636, ..., 0.03491157, 0.03492795,
#          0.02240689]], dtype=float32),
#  'Where is Surzhyk used?': array([[ 0.01132174, -0.00330299,  0.03307221, ...,  0.02212956,
#           0.00137048,  0.02240689]], dtype=float32),
#  'Homer interprets Apollo as a terrible god (δεινὸς θεός) who brings death and disease with his arrows, but who can also heal, possessing a magic art that separates him from the other Greek gods.': array([[0.04293043, 0.03545635, 0.06030454, ..., 0.05525712, 0.02421395,
#          0.02751719]], dtype=float32),
#  "Compact fluorescent lamps (aka 'CFLs') use less power to supply the same amount of light as an incandescent lamp, however they contain mercury which is a dispose hazard.": array([[0.04404522, 0.03330923, 0.08318225, ..., 0.04165663, 0.04904748,
#          0.02316613]], dtype=float32),
#  'What are the major branches of Protestantism?': array([[0.02135553, 0.00102811, 0.03957997, ..., 0.03772947, 0.02370168,
#          0.02240689]], dtype=float32),
#  'Where did Victoria visit instead of Spain during the Boer war?': array([[0.06134615, 0.02384542, 0.02162484, ..., 0.05555908, 0.01510508,
#          0.02240689]], dtype=float32),
#  'What year did Cecil Woodham Smith read Victorias biography': array([[0.03540809, 0.0125412 , 0.02266574, ..., 0.03132303, 0.01114047,
#          0.033702  ]], dtype=float32),
#  'How far east of Chengdu is the planned food processing area?': array([[0.01652134, 0.00781837, 0.05566119, ..., 0.03932446, 0.02701599,
#          0.02240689]], dtype=float32),
#  'On which date did China become effective?': array([[0.01231931, 0.01292594, 0.02413653, ..., 0.04025894, 0.00468769,
#          0.02240689]], dtype=float32),
#  'What public figure defended New York in January 2016?': array([[ 0.02300233, -0.00328998,  0.02833829, ...,  0.03273268,
#          -0.00367823,  0.02240689]], dtype=float32),
# ...
#  'Which inventions of the period had a great impact on everyday life?': array([[0.03727217, 0.01272483, 0.02162788, ..., 0.04706133, 0.02744882,
#          0.02240689]], dtype=float32),
#  'Along with pyrometers, what devices can receive inaccurate results if emissivity is not set correctly?': array([[0.03785732, 0.02432621, 0.0530359 , ..., 0.02751134, 0.03496143,
#          0.03182989]], dtype=float32),
#  'Four members of the Assembly made up what Council, responsible for devising policy for Norfolk Island?': array([[0.04352858, 0.04316662, 0.02916169, ..., 0.03574658, 0.00976924,
#          0.02240689]], dtype=float32),
#  'What color causes people to be seen as further away even though distance is the same?': array([[0.04402639, 0.02490998, 0.03814353, ..., 0.0343425 , 0.04096087,
#          0.02240689]], dtype=float32),
#  "What was Ibn Tufail's religion?": array([[0.02677028, 0.02927621, 0.09493815, ..., 0.02435957, 0.02795612,
#          0.0248268 ]], dtype=float32),
#  'What university offers technical training?': array([[ 0.03241196, -0.01926979,  0.02486649, ...,  0.0608611 ,
#           0.03135588,  0.05414627]], dtype=float32),
#  "Israel's national Holocaust museum, Yad Vashem, is the world central archive of Holocaust-related information.": array([[0.01948182, 0.02682413, 0.03066873, ..., 0.03058607, 0.03781284,
#          0.0247507 ]], dtype=float32),
#  'He started writing his book Philosophy of the Revolution during the siege.': array([[0.04020298, 0.03533559, 0.02360751, ..., 0.05010162, 0.02871071,
#          0.03803197]], dtype=float32),
#  'What is never associated with being boorish?': array([[0.01490952, 0.02298982, 0.02906659, ..., 0.01273303, 0.01289093,
#          0.02240689]], dtype=float32),
#  'Usually, a federation is formed at two levels: the central government and the regions (states, provinces, territories), and little to nothing is said about second or third level administrative political entities.': array([[0.05119783, 0.02732759, 0.05945892, ..., 0.04427115, 0.03262786,
#          0.02396504]], dtype=float32),
#  'Joe Martin, the Republican Speaker from 1947 to 1949 and again from 1953 to 1955, wrote that Eisenhower "never surrounded himself with assistants who could solve political problems with professional skill.': array([[0.05052917, 0.0319865 , 0.06153361, ..., 0.04998421, 0.02127375,
#          0.02657869]], dtype=float32),
#  'What has only a 1x write speed?': array([[0.01739455, 0.0352908 , 0.03019739, ..., 0.02460958, 0.02142624,
#          0.02240689]], dtype=float32),
#  'Ann Arbor became a focal point for political activism and served as a hub for the civil-rights movement and anti-Vietnam War movement, as well as various student movements.': array([[0.07535019, 0.0406257 , 0.038235  , ..., 0.05842515, 0.05776448,
#          0.03791527]], dtype=float32),
#  "What is Oklahoma's largest city?": array([[ 0.02938859,  0.0214717 ,  0.03312078, ...,  0.04057575,
#          -0.00367823,  0.02456831]], dtype=float32),
#  "Who establishes the doctrines of the Jehovah's Witnesses?": array([[0.02885448, 0.00615754, 0.02647737, ..., 0.04595222, 0.03147177,
#          0.02518597]], dtype=float32),
#  "What percentage of the City of Boston's population is 20 to 24?": array([[0.02310745, 0.03545937, 0.02004478, ..., 0.04926138, 0.01394343,
#          0.02240689]], dtype=float32),
#  'The abbey was recognised as what until 1556?': array([[0.05115952, 0.01196153, 0.02310871, ..., 0.02835691, 0.00356263,
#          0.02240689]], dtype=float32),
#  'What type of architecture did Pugin consider truly Christian?': array([[2.6669942e-02, 6.6139852e-05, 3.0006986e-02, ..., 4.1452751e-02,
#          2.3724310e-02, 3.5681672e-02]], dtype=float32),
#  'In particular, Madhava of Sangamagrama is considered the "founder of mathematical analysis".': array([[0.00968965, 0.00530952, 0.0496779 , ..., 0.05255497, 0.07753465,
#          0.0370437 ]], dtype=float32),
#  "Where are the Women's games played?": array([[0.03697117, 0.03158428, 0.02147643, ..., 0.03573578, 0.01641284,
#          0.02508758]], dtype=float32),
#  'What have been included with emulators on Playstation Portable?': array([[0.05398559, 0.01314467, 0.03527636, ..., 0.02839296, 0.00948107,
#          0.02240689]], dtype=float32),
#  'In fact, this was the same title that Kublai Khan had offered the Sakya Phagpa lama, but Deshin Shekpa persuaded the Yongle Emperor to grant the title to religious leaders of other Tibetan Buddhist sects.': array([[0.04990873, 0.03050224, 0.03256102, ..., 0.03777934, 0.04117334,
#          0.02488436]], dtype=float32),
#  'No protests or incidents were reported.': array([[ 0.05205291,  0.00759066,  0.07956975, ..., -0.00287253,
#           0.00241223,  0.02240689]], dtype=float32),
#  "What problems did Sheptycki say 'organizational pathologies' have caused for police?": array([[0.05481256, 0.04222424, 0.05826418, ..., 0.00378494, 0.01310197,
#          0.02954217]], dtype=float32),
#  'Generally however, it is the composers who are remembered more than the performers.': array([[0.04593603, 0.00783454, 0.0259205 , ..., 0.03427687, 0.02808779,
#          0.02240689]], dtype=float32),
#  'What was the name of the settlement that was assessed after the evactuation?': array([[0.03010175, 0.01733614, 0.02751695, ..., 0.0255506 , 0.01334549,
#          0.02240689]], dtype=float32),
#  'As well, in the Baroque era, many works that were designed for basso continuo accompaniment do not specify which instruments should play the accompaniment or exactly how the chordal instrument (harpsichord, lute, etc.)': array([[0.05249014, 0.02870031, 0.07014672, ..., 0.03889114, 0.05428588,
#          0.02240689]], dtype=float32),
#  'Even mathematics had a religious impulse behind its teachings.': array([[0.03292121, 0.01002699, 0.02299616, ..., 0.03655134, 0.04362652,
#          0.02240689]], dtype=float32),
#  'What are some catgories of respective memory?': array([[ 0.02621577, -0.00087863,  0.03946904, ...,  0.01558103,
#           0.04129577,  0.02240689]], dtype=float32),
#  'Hispanic or Latino of any race were 2.6% of the population.': array([[0.04213644, 0.00716277, 0.0252717 , ..., 0.05599655, 0.0284044 ,
#          0.02782541]], dtype=float32),
#  'Margaret Thatcher later described the mindset she believed had befallen the British political establishment as "Suez syndrome", from which Britain did not recover until the successful recapture of the Falkland Islands from Argentina in 1982.': array([[0.0598604 , 0.04126801, 0.05742528, ..., 0.05601384, 0.03104065,
#          0.05420732]], dtype=float32),
#  'A marker that imposes restriction on the behavior of others is what kind of boundary?': array([[0.01831519, 0.00463325, 0.04836272, ..., 0.04127241, 0.02834531,
#          0.03023007]], dtype=float32),
#  'What is New Schools colloquially known as?': array([[2.0585293e-02, 3.4756999e-05, 3.3832431e-02, ..., 2.9042820e-02,
#          1.5828295e-02, 2.2406895e-02]], dtype=float32),
#  'It was established before the fall of the Ming, but it became mature only after 1661, following the death of the Shunzhi Emperor and the accession of his son, the Kangxi Emperor.': array([[0.03076134, 0.0187812 , 0.03076855, ..., 0.04816604, 0.03258505,
#          0.02874969]], dtype=float32),
#  'What is meant by NOP chemicals?': array([[ 0.02177327,  0.00928757,  0.06204989, ...,  0.02473777,
#          -0.00367823,  0.02240689]], dtype=float32),
#  'In what year did George become King?': array([[ 0.03792695,  0.01568097,  0.04129282, ...,  0.02468232,
#          -0.00308069,  0.02240689]], dtype=float32),
#  'Which family member commonly sent an adult married offspring away with their portion of the families fortune?': array([[0.03726357, 0.06856792, 0.03777264, ..., 0.0528484 , 0.03807298,
#          0.02240689]], dtype=float32),
#  "In February 1955, Eisenhower dispatched the first American soldiers to Vietnam as military advisors to Diem's army.": array([[0.05602087, 0.05629754, 0.03590379, ..., 0.040427  , 0.01320965,
#          0.03558099]], dtype=float32),
#  'Which amendment contains the Equal Protection Clause?': array([[0.04479433, 0.02296611, 0.03966928, ..., 0.00603326, 0.04221466,
#          0.02240689]], dtype=float32),
#  'Their troops occupied Nanjing in December and carried out the systematic and brutal Nanking Massacre (the "Rape of Nanking").': array([[0.04718356, 0.03610661, 0.04549086, ..., 0.03468781, 0.03523123,
#          0.03300986]], dtype=float32),
#  'Ajayi states that the book forces readers to question issues about race, class, and society, but that it was not written to resolve them.': array([[0.04220685, 0.03119541, 0.05787699, ..., 0.02952417, 0.04009154,
#          0.03381291]], dtype=float32),
#  'What territories were annexed by Austria-Hungary in 1908?': array([[ 0.0483139 , -0.01265868,  0.02349816, ...,  0.01314815,
#           0.04603617,  0.02240689]], dtype=float32),
#  'How ling did it take the It Gets Better Project video to draw such a huge response?': array([[0.05779773, 0.02133343, 0.03859995, ..., 0.05753626, 0.01053667,
#          0.03592704]], dtype=float32),
#  'What are these districts known as?': array([[ 0.0169902 , -0.00897409,  0.02498698, ...,  0.02349621,
#           0.01627107,  0.02240689]], dtype=float32),
#  "What is the general opinion of the difficulty level of Whitehead's work in math?": array([[0.03681434, 0.0069638 , 0.04391812, ..., 0.05037107, 0.02267764,
#          0.03414466]], dtype=float32),
#  'When a down begins, how far away must the American defending team be?': array([[0.03184353, 0.04272877, 0.02548165, ..., 0.04413078, 0.00977544,
#          0.02240689]], dtype=float32),
#  'What did European regulators introduce to increase the oversight of banks?': array([[0.04165224, 0.01656633, 0.03164823, ..., 0.03141157, 0.00663613,
#          0.02252011]], dtype=float32),
#  'In what year did the synod in Leptines rant against the excesses of the festival?': array([[0.03792695, 0.01374303, 0.01855448, ..., 0.02643246, 0.02147206,
#          0.02702171]], dtype=float32),
#  'How many people are in Boston during work hours?': array([[ 0.03656665,  0.00593058,  0.02203144, ...,  0.02864435,
#          -0.00111192,  0.02240689]], dtype=float32),
#  'What does a power factor of 1 mean?': array([[0.01780446, 0.01160261, 0.04573792, ..., 0.0308378 , 0.02975161,
#          0.02299579]], dtype=float32),
#  'What was Namibia previously called?': array([[0.02580903, 0.01289997, 0.03723325, ..., 0.02242974, 0.0147673 ,
#          0.02543923]], dtype=float32),
#  'When was the first documented translation efforts by foreign Buddhist monks in China?': array([[0.03326932, 0.02143613, 0.02634879, ..., 0.02694383, 0.01845144,
#          0.02240689]], dtype=float32),
#  'With what action did the Qin bring together the Chinese Warring States?': array([[0.03785429, 0.02119537, 0.01561088, ..., 0.02257835, 0.01753271,
#          0.02240689]], dtype=float32),
#  'Who was in charge of the Soviet rocket engineer team that went into Germany?': array([[0.03988909, 0.04459493, 0.04826629, ..., 0.04426064, 0.0203639 ,
#          0.05367089]], dtype=float32),
#  'What author promoted the active use of Old English?': array([[0.01136417, 0.00214463, 0.02559321, ..., 0.04269802, 0.01955353,
#          0.02240689]], dtype=float32),
#  'There are many accents that are traditionally thought of as London accents.': array([[0.05091184, 0.00408659, 0.02489956, ..., 0.03732255, 0.0086125 ,
#          0.02622131]], dtype=float32),
#  'From 4,167 containers of returned remains, forensic examination identified 4,219 individuals.': array([[0.02612296, 0.0079768 , 0.05622229, ..., 0.0324111 , 0.08196393,
#          0.02240689]], dtype=float32),
#  'Socioeconomic factors, in combination with early but enduring views of race, have led to considerable suffering within disadvantaged racial groups.': array([[0.06120316, 0.0246146 , 0.02916106, ..., 0.03790838, 0.06375873,
#          0.02798022]], dtype=float32),
#  'Aside from finding out what underlying phonemes are there what does the phnological study of a language tray to find out about minimal pairs?': array([[0.05746919, 0.04429374, 0.0444878 , ..., 0.06685094, 0.04605476,
#          0.02240689]], dtype=float32),
#  'Purchases of Italian bonds by the central bank, for example, were intended to dampen international speculation and strengthen portfolios in the private sector and also the central bank.': array([[0.03898675, 0.02528102, 0.04190559, ..., 0.0482357 , 0.0159898 ,
#          0.04070396]], dtype=float32),
#  'After the Monroe Brothers broke up in 1939, Bill Monroe formed his own group, after a brief time called the Blue Grass Boys, and completed the transition of mandolin styles from a "parlor" sound typical of brother duets to the modern "bluegrass" style.': array([[0.03403619, 0.04759483, 0.03233705, ..., 0.07801283, 0.03341423,
#          0.03475337]], dtype=float32),
#  'What did Pope Benedict XVI continue the gradual reform of?': array([[0.04392547, 0.01286511, 0.02839579, ..., 0.07942471, 0.01864354,
#          0.02240689]], dtype=float32),
#  "What occurance is the greatest factor affecting Bermuda's economy?": array([[0.01750435, 0.0026487 , 0.0406719 , ..., 0.02958627, 0.03772726,
#          0.02436985]], dtype=float32),
#  'should therefore not be taken in isolation from the Quran, and is to be interpreted within the specific context of exonerating Mary and her child from the charges that were made against them and is not a general statement.': array([[0.05524339, 0.05905111, 0.04348566, ..., 0.0447077 , 0.04007075,
#          0.02530614]], dtype=float32),
#  "Shell's plans to drill in the Artic led to protests from which particular environmental group?": array([[0.06004266, 0.02960487, 0.03190085, ..., 0.0294483 , 0.02469282,
#          0.03701268]], dtype=float32),
#  'What is the term for the player that is currently handing the football when play is underway?': array([[0.02763687, 0.02424732, 0.04281085, ..., 0.04771438, 0.0090896 ,
#          0.02240689]], dtype=float32),
#  'Recorded mostly in Honolulu, Hawaii in three weeks, West announced his fourth album, 808s & Heartbreak, at the 2008 MTV Video Music Awards, where he performed its lead single, "Love Lockdown".': array([[0.05346013, 0.0219954 , 0.03787709, ..., 0.04673389, 0.04168693,
#          0.04453243]], dtype=float32),
#  'What term was applied as early as the eighth century to the priests of the tituli of the diocese of Rome?': array([[0.02696785, 0.00838026, 0.01716327, ..., 0.04813293, 0.03931195,
#          0.02240689]], dtype=float32),
#  'In 1992, Gomes directed Udju Azul di Yonta, which was screened in the Un Certain Regard section at the 1992 Cannes Film Festival.': array([[0.03550625, 0.02484076, 0.05528326, ..., 0.04353378, 0.03739702,
#          0.03657315]], dtype=float32),
#  'Who said "The mlecchas are wedded to the creations of their own fancy."': array([[0.01624623, 0.0148377 , 0.05475767, ..., 0.07102554, 0.01436795,
#          0.02298409]], dtype=float32),
#  'The doctrine of the immaculate conception (Mary being conceived free from original sin) is not to be confused with her virginal conception of her son Jesus.': array([[0.03121885, 0.04924663, 0.04726942, ..., 0.07471487, 0.02359623,
#          0.02976091]], dtype=float32),
#  'Popper postulates that such purely behavioural changes are less likely to be lethal for the organism compared to drastic changes of the phenotype.': array([[0.03412211, 0.03853013, 0.03796775, ..., 0.04427844, 0.029556  ,
#          0.02405993]], dtype=float32),
#  'When was the German green party founded in West Germany?': array([[0.04623776, 0.0118782 , 0.02121627, ..., 0.02048399, 0.02568333,
#          0.04483559]], dtype=float32),
#  'How is zinc primarily added to soil?': array([[0.03228306, 0.02060857, 0.0271628 , ..., 0.05085266, 0.03618079,
#          0.02990141]], dtype=float32),
#  'With his shots in the 9th and 10th innings Wrigley Field erupted and Sandberg set the stage for a comeback win that cemented the Cubs as the team to beat in the East.': array([[0.03527775, 0.0347664 , 0.02528805, ..., 0.06175528, 0.04992108,
#          0.04065029]], dtype=float32),
#  ...}

# %%
with open('data/dict_embeddings1.pickle', 'wb') as handle:
    pickle.dump(d1, handle)

# %%
with open('data/dict_embeddings2.pickle', 'wb') as handle:
    pickle.dump(d2, handle)

# %%
del dict_embeddings
